# %%
numbers = [10, 20, 30, 40]
print(numbers)
# Out:
# [10, 20, 30, 40]

# %%
numbers = {1, 2, 3, 4}
print(numbers)
# Out:
# {1, 2, 3, 4}

# %%
data = {1, 2, 2, 3, 4}
print(data)
# Out:
# {1, 2, 3, 4}

# %%
numbers = (10, 20, 30)
print(numbers)
# Out:
# (10, 20, 30)
